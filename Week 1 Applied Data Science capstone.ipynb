# %% [markdown]
# <h1>It is first notebook of Applied Data Science Capstone Week 1</h1>

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
